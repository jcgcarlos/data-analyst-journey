# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ##### Using the "+ Markdown" you can write non-code texts that can serve as your comments or notes.

# %% [markdown]
# To know more about Git/GitHub visit these links:
# 1. https://docs.github.com/en/get-started/git-basics/set-up-git
# 2. https://docs.github.com/en/get-started/start-your-journey/hello-world
# 3. https://gitimmersion.com/

# %% [markdown]
# ## Python Numbers

# %%
1+1
# Out:
# 2

# %%
3-2
# Out:
# 1

# %%
6*6
# Out:
# 36

# %%
24/2
# Out:
# 12.0

# %%
2**4
# Out:
# 16

# %%
2+10*5/4
# Out:
# 14.5

# %%
(2+4) * (6+10)
# Out:
# 96

# %% [markdown]
# ##### Module or "Mod" Operator - returns the remainder, check if a number is evenly divisible by another number

# %%
7/4
# Out:
# 1.75

# %%
7%4
# Out:
# 3

# %%
50%5
# Out:
# 0

# %%
33%3
# Out:
# 0

# %% [markdown]
# ## Variable Assignments

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a + a
# Out:
# 20

# %%
a = a + a

# %%
a
# Out:
# 20

# %%
a
# Out:
# 40

# %%
type(a)
# Out:
# int

# %%
a = 30.1

# %%
type(a)
# Out:
# float

# %%
my_income = 1000
tax_rate = 0.1
my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 100.0
