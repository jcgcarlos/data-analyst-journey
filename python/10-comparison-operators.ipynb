# %% [markdown]
# Comparison Operators

# %%
# Checks for equality
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
# Can also be used in strings
'hello' == 'bye'
# Out:
# False

# %%
# Considers capitalization
'Hello' == 'hello'
# Out:
# False

# %%
# Float
2.0 == 2
# Out:
# True

# %%
# Inequality use exlamation mark "!"
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1 < 3
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
4 <= 1
# Out:
# False

# %% [markdown]
# Chaining Comparison Operators

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
'h' == 'h' and 2 == 2
# Out:
# True

# %%
1 == 1 or 2 == 2
# Out:
# True

# %%
100 == 1 or 2 == 2
# Out:
# True

# %%
not 1 == 1
# Out:
# False
