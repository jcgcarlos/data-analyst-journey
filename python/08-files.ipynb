# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is the second line
# this is the third line
# Out:
# Overwriting myfile.txt

# %%
# Open a txt file
myfile = open('myfile.txt')

# %%
# Returns an error if txt file doesn't exist
myfile = open('test_wrong.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Returns an error if txt file doesn't exist
# ----> 2 myfile = open('test_wrong.txt')
#
# File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_wrong.txt'

# %%
pwd
# Out:
# 'c:\\Users\\john.carlos\\Documents\\GitHub\\data-analyst-journey\\python\\Week 1 Python Object and Data Structure Basics'

# %%
myfile = open('myfile.txt')

# %%
# Method to read/open the txt file
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
# Resets back the cursor to go back at the start
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %%
# Close the txt file after opening it
myfile.close()

# %%
# To not to worry about closing the txt file use "with"

with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
# 'r' = read
# 'w' = write
# 'a' = append

with open('myfile.txt', mode='r') as myfile:
    contents = myfile.read()

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Writing my_new_file.txt

# %%
# Read mode
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
# Append
with open('my_new_file.txt',mode='a') as f:
    f.write('FOUR ON FOURTH')

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# FOUR ON FOURTH

# %%
# Write
with open('abcdefg.txt',mode='w') as f:
    f.write('I CREATED THIS FILE!')

# %%
with open('abcdefg.txt',mode='r') as f:
    print(f.read())
# Out:
# I CREATED THIS FILE!
