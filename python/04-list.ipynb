# %%
mylist = ['String', 2, 100.3]

# %%
mylist
# Out:
# ['String', 2, 100.3]

# %%
mylist = ['one', 'two', 'three']

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %%
another_list = ['four', 'five']

# %%
new_list = mylist + another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0] = 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
new_list.append('six')

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.pop()
# Out:
# 'six'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'five'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four']

# %%
new_list.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['two', 'three', 'four']

# %%
new_list = ['a', 'd', 'e', 'g', 'f', 'z']
num_list = [1,5,2,7,8]

# %%
# Sort occurs in place
new_list.sort()

# %%
new_list
# Out:
# ['a', 'd', 'e', 'f', 'g', 'z']

# %%
num_list.sort()
sorted_num_list = num_list

# %%
sorted_num_list
# Out:
# [1, 2, 5, 7, 8]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 7, 5, 2, 1]
